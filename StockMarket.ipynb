# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-633e97bb-71b5-4970-864e-6c1550c19be7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-633e97bb-71b5-4970-864e-6c1550c19be7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

# %%
data = pd.read_excel(io.BytesIO(uploaded['MinProj.xlsx']))

# %%
data.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   datetime64[ns]
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 55.3 KB

# %%
data.shape
# Out:
# (1009, 7)

# %%
data.count()
# Out:
# Date         1009
# Open         1009
# High         1009
# Low          1009
# Close        1009
# Adj Close    1009
# Volume       1009
# dtype: int64

# %%
data.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
data.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
data.count()
# Out:
# Date         1009
# Open         1009
# High         1009
# Low          1009
# Close        1009
# Adj Close    1009
# Volume       1009
# dtype: int64

# %%
data.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %% [markdown]
# Sorting the Given Values

# %%
sorted_df=data.sort_values('Volume',ascending=True).head(10)
sorted_df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 728 2020-12-24  515.119995  519.349976  512.210022  513.969971  513.969971
# 982 2021-12-29  610.710022  613.979980  604.679993  610.539978  610.539978
# 883 2021-08-09  521.150024  522.669983  517.989990  519.969971  519.969971
# 896 2021-08-26  546.159973  552.599976  545.900024  550.119995  550.119995
# 979 2021-12-23  616.400024  616.880005  607.570007  614.090027  614.090027
# 983 2021-12-30  612.989990  620.609985  611.239990  612.090027  612.090027
# 885 2021-08-11  517.000000  519.570007  509.769989  512.400024  512.400024
# 886 2021-08-12  511.859985  513.000000  507.200012  510.720001  510.720001
# 876 2021-07-29  519.960022  520.780029  513.789978  514.250000  514.250000
# 863 2021-07-12  540.299988  540.650024  532.919983  537.309998  537.309998
#
#       Volume
# 728  1144000
# 982  1287200
# 883  1367800
# 896  1595500
# 979  1621100
# 983  1625100
# 885  1673900
# 886  1685700
# ...

# %% [markdown]
# Asccending ORder Sort

# %%
sorted_df1=data.sort_values('High',ascending=True).head(10)
sorted_df1
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 223 2018-12-24  242.000000  250.649994  233.679993  233.880005  233.880005
# 224 2018-12-26  233.919998  254.500000  231.229996  253.669998  253.669998
# 225 2018-12-27  250.110001  255.589996  240.100006  255.570007  255.570007
# 4   2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# 5   2018-02-12  252.139999  259.149994  249.000000  257.950012  257.950012
# 6   2018-02-13  257.290009  261.410004  254.699997  258.269989  258.269989
# 226 2018-12-28  257.940002  261.910004  249.800003  256.079987  256.079987
# 222 2018-12-21  263.829987  264.500000  241.289993  246.389999  246.389999
# 411 2019-09-24  262.500000  265.000000  252.279999  254.589996  254.589996
# 203 2018-11-23  260.109985  265.500000  256.839996  258.820007  258.820007
#
#        Volume
# 223   9547600
# 224  14402700
# 225  12235200
# 4    16906900
# 5     8534900
# 6     6855200
# 226  10992800
# 222  21397600
# ...

# %%
data.describe().transpose()
# Out:
#             count          mean           std           min           25%  \
# Open       1009.0  4.190597e+02  1.085375e+02  2.339200e+02  3.314900e+02
# High       1009.0  4.253207e+02  1.092630e+02  2.506500e+02  3.363000e+02
# Low        1009.0  4.123740e+02  1.075559e+02  2.312300e+02  3.260000e+02
# Close      1009.0  4.190007e+02  1.082900e+02  2.338800e+02  3.316200e+02
# Adj Close  1009.0  4.190007e+02  1.082900e+02  2.338800e+02  3.316200e+02
# Volume     1009.0  7.570685e+06  5.465535e+06  1.144000e+06  4.091900e+06
#
#                     50%           75%           max
# Open       3.777700e+02  5.091300e+02  6.923500e+02
# High       3.830100e+02  5.156300e+02  7.009900e+02
# Low        3.708800e+02  5.025300e+02  6.860900e+02
# Close      3.786700e+02  5.090800e+02  6.916900e+02
# Adj Close  3.786700e+02  5.090800e+02  6.916900e+02
# Volume     5.934500e+06  9.322400e+06  5.890430e+07

# %% [markdown]
# Top 10 Highest trades in Volume

# %%
most_volume = data.query('Volume>0', inplace = False).sort_values('Volume', ascending = False)
most_volume[:10]
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 998 2022-01-21  400.429993  409.149994  379.989990  397.500000  397.500000
# 112 2018-07-17  346.950012  385.000000  344.000000  379.480011  379.480011
# 428 2019-10-17  304.489990  308.750000  288.299988  293.350006  293.350006
# 49  2018-04-17  329.660004  338.619995  323.769989  336.059998  336.059998
# 744 2021-01-20  565.419983  593.289978  556.859985  586.340027  586.340027
# 177 2018-10-17  378.329987  380.000000  356.500000  364.700012  364.700012
# 999 2022-01-24  383.910004  387.260010  351.459991  387.149994  387.149994
# 364 2019-07-18  323.760010  329.850006  320.299988  325.209991  325.209991
# 240 2019-01-18  351.970001  353.000000  336.730011  339.100006  339.100006
# 616 2020-07-17  494.869995  503.589996  484.140015  492.989990  492.989990
#
#        Volume
# 998  58904300
# 112  58410400
# 428  38258900
# 49   33866500
# 744  32637500
# 177  32610900
# 999  32346000
# 364  31287100
# ...

# %% [markdown]
# High value in 9th row

# %%
data[["High"]].iloc[8]
# Out:
# High    280.5
# Name: 8, dtype: float64

# %% [markdown]
# Low value in 9th row

# %%
data[["Low"]].iloc[8]
# Out:
# Low    267.630005
# Name: 8, dtype: float64

# %% [markdown]
# EDA

# %%
plt.figure(figsize=(15,5))

# %%
plt.plot(data['Close'])
plt.title('Close Price',fontsize=15)
plt.ylabel('Price in dollars')
plt.show()

# %% [markdown]
# the prices have taken an upward trend but goes down at the end

# %%
data.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %% [markdown]
# We observe that data in 'Close' column is same as the data available in 'Adj Close'

# %% [markdown]
# Let's check whether if this applies for all the rows

# %%
data[data['Close'] == data['Adj Close']].shape
# Out:
# (1009, 7)

# %% [markdown]
# Here we conclude that all rows of columns 'Close' and 'Adj Close' have same data. So we can drop this column

# %%
data=data.drop(['Adj Close'],axis=1)

# %% [markdown]
# check once again for null

# %%
data.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %% [markdown]
# Now lets draw the distribution plot

# %%
features = ['Open','High','Low','Close','Volume']

plt.subplots(figsize=(20,10))

for i, col in enumerate(features):
  plt.subplot(2,3,i+1)
  sns.distplot(data[col])
plt.show()
# Out:
# <ipython-input-34-02936d21dbd3>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,3,i+1)
# <ipython-input-34-02936d21dbd3>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[col])
# <ipython-input-34-02936d21dbd3>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# ...

# %% [markdown]
# In the distribution plot, we can see two peaks which means the data has varied significantly in two regions. And the Volume data is left-skewed.

# %% [markdown]
# Now plot the boxed plot

# %%
plt.subplots(figsize=(20,10))
for i, col in enumerate(features):
  plt.subplot(2,3,i+1)
  sns.boxplot(data[col])
plt.show()
# Out:
# <ipython-input-36-5f89f3862cdf>:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,3,i+1)

# %% [markdown]
# Feature Engineering

# %%
data['Date'] = data['Date'].apply(lambda x: str(x))

# %%
data.dtypes
# Out:
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# dtype: object

# %%
splitted = data['Date'].str.split('-', expand=True)

data['day'] = splitted[2].astype('int')
data['month'] = splitted[1].astype('int')
data['year'] = splitted[0].astype('int')

data.head()
# Out:
#          Date        Open        High         Low       Close    Volume  day  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  11896100    5
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  12595800    6
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998   8981500    7
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006   9306700    8
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  16906900    9
#
#    month  year
# 0      2  2018
# 1      2  2018
# 2      2  2018
# 3      2  2018
# 4      2  2018

# %% [markdown]
# Therefore we will have 3 columns 'day', 'month', 'year' derived from 'Date' column

# %%
data['is_quarter_end'] = np.where(data['month']%3==0,1,0)
data.head()
# Out:
#          Date        Open        High         Low       Close    Volume  day  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  11896100    5
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  12595800    6
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998   8981500    7
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006   9306700    8
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  16906900    9
#
#    month  year  is_quarter_end
# 0      2  2018               0
# 1      2  2018               0
# 2      2  2018               0
# 3      2  2018               0
# 4      2  2018               0

# %%
data_grouped = data.groupby('year').mean()
plt.subplots(figsize=(20,10))

for i, col in enumerate(['Open', 'High', 'Low', 'Close']):
  plt.subplot(2,2,i+1)
  data_grouped[col].plot.bar()
plt.show()
# Out:
# <ipython-input-52-48828baf94c1>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_grouped = data.groupby('year').mean()
# <ipython-input-52-48828baf94c1>:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,2,i+1)

# %% [markdown]
# From this graph, we can conclude that stock prices have decreased from 2021 to 2022

# %%
data.groupby('is_quarter_end').mean()
# Out:
# <ipython-input-53-a1c6d32ebebf>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('is_quarter_end').mean()
#                       Open        High         Low       Close        Volume  \
# is_quarter_end
# 0               418.681368  424.889821  412.112068  418.699791  7.951664e+06
# 1               419.814037  426.179910  412.896440  419.600831  6.810988e+06
#
#                       day     month         year
# is_quarter_end
# 0               15.715774  6.087798  2019.622024
# 1               15.721068  7.442136  2019.543027

# %% [markdown]
# Here are some important observations that can be infered from above
#
#
# *  Prices are higher in the months which are quarter end as compared to that of the non-quarter end months
# *   The volume of trades is lower in the months which are quarter end

# %%
data['open-close']  = data['Open'] - data['Close']
data['low-high']  = data['Low'] - data['High']
data['target'] = np.where(data['Close'].shift(-1) > data['Close'], 1, 0)

# %% [markdown]
# Above we have added some more columns which will help in the training of our model. We have added the target feature which is a signal whether to buy the stock or not. We will train our model to predict this only.

# %% [markdown]
#  Let's check whether the target is balanced or not using a pie chart.

# %%
plt.pie(data['target'].value_counts().values,
        labels=[0, 1], autopct='%1.1f%%')
plt.show()

# %% [markdown]
# When we add features to our dataset we have to ensure that there are no highly correlated features as they do not help in the learning process of the algorithm.

# %%
plt.figure(figsize=(10, 10))

sns.heatmap(data.corr() > 0.9, annot=True, cbar=False)
plt.show()
# Out:
# <ipython-input-56-13f60aa63f53>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr() > 0.9, annot=True, cbar=False)

# %% [markdown]
# Data Splitting and Normalization

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
features = data[['open-close', 'low-high', 'is_quarter_end']]
target = data['target']

scaler = StandardScaler()
features = scaler.fit_transform(features)

X_train, X_valid, Y_train, Y_valid = train_test_split(
    features, target, test_size=0.1, random_state=2022)
print(X_train.shape, X_valid.shape)
# Out:
# (908, 3) (101, 3)

# %% [markdown]
# After selecting the features to train the model on we should normalize the data because normalized data leads to stable and fast training of the model. After that whole data has been split into two parts with a 90/10 ratio so, that we can evaluate the performance of our model on unseen data.

# %% [markdown]
# Model Development and Evaluation

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')

models = [LogisticRegression(), SVC(
  kernel='poly', probability=True), XGBClassifier()]

for i in range(3):
  models[i].fit(X_train, Y_train)

  print(f'{models[i]} : ')
  print('Training Accuracy : ', metrics.roc_auc_score(
    Y_train, models[i].predict_proba(X_train)[:,1]))
  print('Validation Accuracy : ', metrics.roc_auc_score(
    Y_valid, models[i].predict_proba(X_valid)[:,1]))
  print()
# Out:
# LogisticRegression() :
# Training Accuracy :  0.5406138368447911
# Validation Accuracy :  0.582598235765838
#
# SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.5326091711015528
# Validation Accuracy :  0.4947874899759423
#
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
# ...

# %% [markdown]
# PLot Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

cm = confusion_matrix(Y_valid, models[0].predict(X_valid))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.colorbar()
plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.show()

# %% [markdown]
# We can observe that the accuracy achieved by the state-of-the-art ML model is no better than simply guessing with a probability of 50%. Possible reasons for this may be the lack of data or using a very simple model to perform such a complex task as Stock Market prediction.
